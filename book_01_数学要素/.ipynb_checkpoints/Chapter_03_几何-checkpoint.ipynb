# %% [markdown]
# # 3 几何(Geometry)

# %% [markdown]
# ![image.png](attachment:eaeae79d-4953-4c0c-a94d-fef30539f0bf.png)

# %% [markdown]
# ## 3.1 几何缘起：根植大地，求索星空

# %% [markdown]
# 主要为各个科学家的贡献<font color="blue">(略)</font>

# %% [markdown]
# ## 3.2 点动成线，线动成面，面动成体

# %% [markdown]
# ![image.png](attachment:f9bbeb91-a073-4c83-9233-6203be52167c.png)

# %% [markdown]
# ### 点

# %% [markdown]
# 常见的几种点：<font color="blue">端点</font>(endpoint)、<font color="blue">中点</font>(midpoint)、<font color="blue">起点</font>(initial point)、<font color="blue">终点</font>(terminal point)、<font color="blue">圆心</font>(center)、<font color="blue">切点</font>(point of tangency)、<font color="blue">顶点</font>(vertex)、<font color="blue">交点</font>(point of intersection)。点和点之间的线段长度叫<font color="blue">距离</font>(distance)
# ![image.png](attachment:5a2bb66c-2f10-47b3-887b-ec8de5027e4b.png)

# %% [markdown]
# ### 线

# %% [markdown]
# <font color="blue">直线</font>(line)<font color="blue">沿两个方向无限延伸</font>(extends in both directions without end)，<font color="blue">没有端点</font>(has no endpoints)。<font color="blue">射线</font>(ray 或 half-line)开始于一个端点，仅沿一个方向无限延伸。<font color="blue">线段</font>(line segment)有两个<font color="blue">端点</font>(endpoint)

# %% [markdown]
# 给定参考系，线可以分为<font color="blue">水平线</font> (horizontal line)、<font color="blue">斜线</font>(oblique line)、<font color="blue">竖直线</font>(vertical line)

# %% [markdown]
# <font color="blue">边</font>(edge)、<font color="blue">曲线</font>(curve 或 curved line)、<font color="blue">等高线</font>(contour line)、<font color="blue">法线</font>(normal line)、<font color="blue">切线</font>(tangent line)、<font color="blue">割线</font>(secanr line)

# %% [markdown]
# ![image.png](attachment:6c7f79dd-784a-4f13-80cc-de32f12a8e8b.png)

# %% [markdown]
# 线与线之间有四种常见的关系：<font color="blue">平行</font>(parallel)、<font color="blue">相交</font>(intersecting)、<font color="blue">垂直</font>(perpendicular)和<font color="blue">重合</font>(coinciding)

# %% [markdown]
# 可视化用到不同样式的线型，比如<font color="blue">实线</font>(solid line 或 continuous line)、<font color="blue">粗实线</font>(heavy solid line 或 continuous thick line)、<font color="blue">点虚线</font>(dotted line)、<font color="blue">短划线</font>(dashed ;ine)、<font color="blue">点划线</font>(dash-dotted line)
# ![image.png](attachment:8640dd29-5dfc-4844-b563-032433a49b35.png)

# %% [markdown]
# ### 欧几里得的五个公理

# %% [markdown]
# - 任意两点可以画一条直线;
# - 任意线段都可以无限延伸成一条直线;
# - 给定任意线段，以该线段为半径，以一个端点为圆心，可以画一个圆;
# - 所有直角都全等;
# - 两直线被第三条直线所截，如果同侧两内角之和小于两个直角之和，则两条直线则会在该侧相交。

# %% [markdown]
# ### 正多变形

# %% [markdown]
# <font color="blue">正多边形</font>(regular polygons)是边长相等的多边形；正多边形内角相等
# ![image.png](attachment:72993bdd-b0a9-42c1-97b0-c2bcc55b225e.png)

# %%
# 绘制正多边形
import matplotlib.pyplot as plt
from matplotlib.patches import RegularPolygon, Circle
import numpy as np

for num_vertices in [3, 4, 5, 6, 7, 8]:

    fig, ax = plt.subplots()
    # 设置坐标轴横纵比例相等
    ax.set_aspect("equal")

    # 中心在 (0, 0)，边数为当前 num_vertices 半径 1，透明度 0.2，边框黑色
    hexagon_inner = RegularPolygon((0, 0), numVertices=num_vertices, 
                                   radius=1, alpha=0.2, edgecolor="k")

    ax.add_patch(hexagon_inner)

    plt.axis("off")

    plt.xlim(-1.5, 1.5)
    plt.ylim(-1.5, 1.5)
    plt.show()

# %% [markdown]
# ### 三维几何体

# %% [markdown]
# 主要为对与多面体的介绍 <font color="blue">(略)</font>

# %% [markdown]
# ### 几何变换

# %% [markdown]
# 可以通过<font color="blue">平移</font>(translate)、<font color="blue">旋转</font>(rotation)、<font color="blue">镜像</font>(reflection)、<font color="blue">缩放</font>(scaling)、<font color="blue">投影</font>(projection)等变换某个图形来生成新的图形
# ![image.png](attachment:72ddaac8-0e4e-419c-a35d-e6db93e0ae3e.png)

# %% [markdown]
# ## 3.3 角度和弧度

# %% [markdown]
# ### 角度 / 弧度

# %% [markdown]
# <font color="blue">角度</font>(degree), <font color="blue">弧度</font>(radian)
# 在 `math` 库中，`math.radians()` 函数将角度转换为弧度；`math.degrees()` 将弧度转换为角度。
# 在 `NumPy` 中， `numpy.rad2deg()` 函数将弧度转化为角度，`numpy.deg2red()` 将角度转化为弧度。

# %% [markdown]
# ### 正角 / 负角

# %% [markdown]
# <font color="blue">略</font>

# %% [markdown]
# ### 锐角、直角、钝角

# %% [markdown]
# <font color="blue">略</font>

# %% [markdown]
# ## 3.4 勾股定理到三角函数

# %% [markdown]
# ### 勾股定理

# %% [markdown]
# ![image.png](attachment:04cd84f7-17c4-4b5e-bfb1-4b6e2122a4a6.png)
#
# ![image.png](attachment:8e50ca21-5299-4d83-922a-ab489d096a6a.png)

# %% [markdown]
# ### 三角函数

# %% [markdown]
# <font color="blue">三角函数</font>(trigonometric)的自变量为弧度角度。
#
# $\theta$ 的<font color="blue">正弦</font>(sine)是对边 $a$ 与斜边 $c$ 的比值:
#
# ![image.png](attachment:f98cd69a-b565-4aaa-ba27-b2317a91bbb2.png)
#
# `numpy.sin()` 可以用来计算正弦值，输入为弧度
#
# $\theta$的<font color="blue">余弦</font>(cosine)是邻边 $b$ 与斜边 $c$ 的比值:
#
# ![image.png](attachment:01ce902e-faa1-4907-bab0-109f6d650410.png)
#
# `numpy.cos()` 可以用来计算余弦值，输入为弧度
#
# $\theta$的<font color="blue">正切</font>(tangent)是对边 $a$ 与邻边 $b$ 的比值:
#
# ![image.png](attachment:193f7800-3aed-4fac-8310-54afa847cd49.png)
#
# `numpy.tan()` 可以用来计算正切值，输入为弧度
#
#
# $\theta$的<font color="blue">余切</font>(cotangent)是邻边 $b$ 与对边 $a$ 的比值，是正切的倒数:
#
# ![image.png](attachment:320b7692-af2c-435f-8666-588dae749ba7.png)
#
# $\theta$的<font color="blue">正割</font>(secant)是斜边 $c$ 与邻边 $b$ 的比值，是余弦的倒数:
#
# ![image.png](attachment:e35374fa-8e78-4353-a0ba-b592507cab64.png)
#
# $\theta$的<font color="blue">余割</font>(cosecant)是斜边 $c$ 与邻边 $a$ 的比值，是正弦的倒数:
#
# ![image.png](attachment:92880668-5d6e-4047-8a1c-97816891e31a.png)

# %% [markdown]
# ### 反三角函数

# %% [markdown]
# <font color="blue">反三角函数</font>(inverse trigonometric function)则是通过三角函数值来求弧度或角度。
#
# ![image.png](attachment:2cff85ce-b746-48fa-b0d8-42b074f0ad6f.png)

# %% [markdown]
# ### 余弦定理

# %% [markdown]
# ![image.png](attachment:ed8894b5-3aaf-46f8-8f69-05f5417adb61.png)
#
# ![image.png](attachment:3fe91614-d5b7-4663-b7ee-d14bffeda137.png)

# %% [markdown]
# ## 3.5 圆周率估算初赛：割圆术

# %% [markdown]
# ### 内接和外切正多边形

# %% [markdown]
# 圆内接正多边形的边长之和，可以用来近似圆的周长的下边界，圆内外切正多边形的边长之和，则可以来接近圆周长的上边界。
# ![image.png](attachment:b4366ace-fd07-4986-a205-9116f8a9c111.png)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import RegularPolygon, Circle
import numpy as np

for num_vertices in [6, 8, 10, 12, 14, 16]:

    fig, ax = plt.subplots()
    ax.set_aspect("equal")

    hexagon_inner = RegularPolygon((0, 0), numVertices=num_vertices,
                                  radius=1, alpha=0.2, edgecolor="k")

    ax.add_patch(hexagon_inner)

    hexagon_outer = RegularPolygon((0, 0), numVertices=num_vertices,
                                  radius=1/np.cos(np.pi/num_vertices),
                                  alpha=0.2, edgecolor="k")
    ax.add_patch(hexagon_outer)

    circle = Circle((0, 0), radius=1, facecolor="none", edgecolor="k")
    ax.add_patch(circle)

    plt.axis("off")

    plt.xlim(-1.5, 1.5)
    plt.ylim(-1.5, 1.5)
    plt.show()

# %% [markdown]
# ### 估算圆周率上下界

# %% [markdown]
# ![image.png](attachment:7fac5498-de7f-4971-a9d2-4958ed2c3be2.png)

# %% [markdown]
# 外切正多边形的周长是估算单位圆周长的上界：
#
# ![image.png](attachment:5f1de81a-444d-485c-bc8e-ff83e032c5a9.png)

# %% [markdown]
# 内接是正多边形的周长是估算单位圆周长的下界：
#
# ![image.png](attachment:b5103661-3cc3-4409-a5dd-1b1e5617d85a.png)

# %% [markdown]
# 圆周率估算的上下界：
#
# ![image.png](attachment:a5dd34aa-ab61-420c-87d7-b00c313efd32.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

n_start = 6
n_stop = 50
n_array = np.linspace(n_start, n_stop, n_stop - n_start + 1)

pi_lower_b = np.sin(np.pi/n_array)*n_array
pi_upper_b = np.tan(np.pi/n_array)*n_array

fig, ax = plt.subplots()

plt.axhline(y=np.pi, color="r", linestyle="-")
plt.plot(n_array, pi_lower_b, color="b")
plt.plot(n_array, pi_upper_b, color="g")
plt.fill_between(n_array, pi_lower_b, pi_upper_b, color="#DEEAF6")
plt.tight_layout()
plt.xlabel("Number of sides, n")
plt.ylabel("Estimate of $\pi$")
# Out:
# Text(42.722222222222214, 0.5, 'Estimate of $\\pi$')

# %% [markdown]
# ### 阿基米德的方法

# %% [markdown]
# ![image.png](attachment:0324f932-eb02-4f52-b176-2c05c1a02273.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

n_start = 6

B_6 = np.sin(np.pi/n_start)*n_start
A_6 = np.tan(np.pi/n_start)*n_start

B_array = []
A_array = []
n_array = [6, 12, 24, 48, 96]

B_i = B_6
A_i = A_6
n_i = n_start

for i in  n_array:
    B_array.append(B_i)
    A_array.append(A_i)

    # updating
    A_i = 2*A_i*B_i/(A_i + B_i)
    B_i = np.sqrt(A_i*B_i)

B_array = np.array(B_array)
A_array = np.array(A_array)
n_array = np.array(n_array)

fig, ax = plt.subplots()

plt.axhline(y=np.pi, color="r", linestyle="-")
plt.plot(n_array, B_array, color="b", marker="x")
plt.plot(n_array, A_array, color="g", marker="x")
plt.fill_between(n_array, B_array, A_array, color="#DEEAf6")
plt.tight_layout()
plt.xticks([6, 12, 24, 48, 96])
plt.xlim((6, 96))
plt.xlabel("Number of sides, n")
plt.ylabel("Estimate of $\pi$")
# Out:
# Text(42.722222222222214, 0.5, 'Estimate of $\\pi$')
