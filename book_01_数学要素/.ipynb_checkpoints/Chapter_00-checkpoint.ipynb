# %% [markdown]
# # 第一章 万物皆数
# ## 第一节：XXXXX
# 分段：两个空格

# %%
a = 1
b = 2
print("a + b = " + str(a + b))
# Out:
# a + b = 3

# %% [markdown]
# ## 第二节：XXXXX
#
# Latex
#
# This is a symbol, $A$
#
# $$
# a + b = 2
# $$

# %%
a = 1
b = 2
print("a + b = " + str(a + b))
# Out:
# a + b = 3
