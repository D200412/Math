# %% [markdown]
# # 8 圆锥曲线(Conic Sections)

# %% [markdown]
# ![image.png](attachment:3d26655f-3dbe-4910-af82-f2eefa6231e2.png)

# %% [markdown]
# ## 8.1 圆锥曲线外传

# %% [markdown]
# <font color="blue">略</font>

# %% [markdown]
# ## 8.2 圆锥曲线：对顶圆锥和截面相交

# %% [markdown]
# 圆锥曲线是通过一个<font color="blue">对顶圆锥</font>(double cone)和一个<font color="blue">截面</font>(cuttingplane)相交得到一系列曲线。圆锥曲线主要分为：<font color="blue">正圆</font>(circle)<font color="blue">椭圆</font>(ellipse)、<font color="blue">抛物线</font>(parabola)和<font color="blue">双曲线</font>(hyperbola)。正圆可以视作椭圆的特殊形态。
#
# ![image.png](attachment:986017f8-5d2e-4df8-8815-b1a2e5d5a7da.png)

# %% [markdown]
# ### 退化圆锥曲线

# %% [markdown]
# <font color="blue">退化圆锥曲线</font>(degenerate conic)
# - <font color="blue">退化双曲线</font>(degenerate hyperbola)为两条相交直线。
# - <font color="blue">退化抛物线</font>(degenerate parabola)可以是一条直线或者两条平行直线。
# - <font color="blue">退化椭圆</font>(degenerate ellipse)为一个点。
#
# ![image.png](attachment:58ac04d4-8b2f-4329-989e-6bc4f77ce0fb.png)

# %% [markdown]
# ## 8.3 正圆：特殊的椭圆

# %% [markdown]
# ![image.png](attachment:f306c2e3-ccfc-4af1-b67b-462ad805c683.png)
#
# 矩阵乘法形式：
#
# ![image.png](attachment:52014d86-20c4-4604-b545-e676c523341b.png)
#
# ![image.png](attachment:44039ebe-137b-4bf1-a125-a34de816a205.png)

# %% [markdown]
# ### 上半圆、下半圆

# %% [markdown]
# <font color="blue">上半圆</font>(upper semicircle)函数:
#
# ![image.png](attachment:2ddb3c5d-4254-4883-b0a6-40434b085b0d.png)
#
# <font color="blue">下半圆</font>(lower semicircle)函数:
#
# ![image.png](attachment:b59fe6c4-4f47-475b-8e87-2b6a766d14cb.png)

# %% [markdown]
# ## 8.4 椭圆：机器学习的多面手

# %% [markdown]
# 椭圆的<font color="blue">长轴</font>(major axis)位于横轴 $x_1$ 上，对应的解析式为:
#
# ![image.png](attachment:25fbf339-cb51-4766-8f2a-98c58e1b121c.png)
#
# 长轴，是指通过连接椭圆上的两个点所能获得的最长线段，椭圆长轴的长度为 $2a
#
# 与之相反，<font color="blue">短轴</font>(minor axis)是通过连接椭圆上的两个点所能获得的最短线段，椭圆短轴长度为 $2b$。一个椭圆长轴和短轴相互垂直。
#
# 长轴的一半被称作<font color="blue">半长轴</font>(semi-major axis)，短轴的一半被称作<font color="blue">半短轴</font>(semi-minor axis)。

# %% [markdown]
# 矩阵乘法形式：
#
# ![image.png](attachment:46a87ef6-5519-43b7-9433-2312e4ea24d1.png)

# %% [markdown]
# 椭圆的长轴位于纵轴 $x_2$ 上，对应的解析式为:
#
# ![image.png](attachment:34796e7a-372e-4f68-9eef-bc433ec0ebe7.png)

# %% [markdown]
# ![image.png](attachment:6998c74d-1da3-4f49-b1d1-71dc40253099.png)

# %% [markdown]
# ### 焦点

# %% [markdown]
# 此外，椭圆的<font color="blue">焦点</font>(单数focus，复数foci)位于椭圆长轴。椭圆上任意一点 $P$ 到两个焦点 $F1$ 和 $F2$ 的距离之和等于 $2a$。
#
# ![image.png](attachment:74324fa8-07a8-450f-ab79-363b15887842.png)

# %% [markdown]
# ### 中心移动

# %% [markdown]
# 中心在 $(c1,c2)$ 的正椭圆。所示椭圆的解析式如下:
#
# ![image.png](attachment:ca023c14-99c6-4e06-b18e-00590048112c.png)

# %% [markdown]
# ## 8.5 旋转椭圆：几何变换的结果

# %% [markdown]
# 椭圆逆时针旋转 $\theta$ 后得到椭圆对应的解析式:
#
# ![image.png](attachment:97c7c0c0-677f-40bb-af3e-f8953ebdb209.png)
#
# 顺时针旋转 $\theta$ 后得到椭圆解析式:
#
# ![image.png](attachment:2d4db92e-a0c9-4f4e-b573-f5541b3cc2e6.png)

# %% [markdown]
# ### 单位圆到椭圆

# %% [markdown]
# ![image.png](attachment:92d188b3-6ccd-40c5-9c36-10ff8624f40f.png)

# %%
from matplotlib import pyplot as plt
from sympy import plot_implicit, symbols, Eq

x1, x2 = symbols("x1 x2")

def plot_curve(Eq_sym):
    h_plot = plot_implicit(Eq_sym, (x1, -2.5, 2.5), (x2, -2.5, 2.5),
                          xlable = r"$\it{x_1}$", ylabel= r"$\it{x_2}$")

# %%
Eq_sym = Eq(x1 ** 2 / 4 + x2 ** 2, 1)
plot_curve(Eq_sym)

# %%
Eq_sym = Eq(x1 ** 2 + x2 ** 2 / 4, 1)
plot_curve(Eq_sym)

# %%
Eq_sym = Eq((x1 - 0.5) ** 2 / 4 + (x2 - 0.5) ** 2, 1)
plot_curve(Eq_sym)

# %%
Eq_sym = Eq((x1 - 0.5) ** 2 + (x2 - 0.5) ** 2 / 4, 1)
plot_curve(Eq_sym)

# %%
Eq_sym = Eq(5 * x1 ** 2 / 8 - 3 * x1 * x2 / 4 + 5 * x2 ** 2 / 8, 1)  
plot_curve(Eq_sym)

# %%
Eq_sym = Eq(5 * x1 ** 2 / 8 + 3 * x1 * x2 / 4 + 5 * x2 ** 2 / 8, 1)  
plot_curve(Eq_sym)

# %% [markdown]
# ## 8.6 抛物线：不止是函数

# %% [markdown]
# 顶点在原点，对称轴位于 $x_2$ 纵轴，开口向上抛物线解析式如下:
#
# ![image.png](attachment:1f3cae82-3e24-4147-82aa-5f3e24537d20.png)
#
# ![image.png](attachment:ef94df50-0f5f-4592-b6bf-ed08595d84df.png)

# %% [markdown]
# ## 8.7 双曲线：引力弹弓的轨迹

# %% [markdown]
# 焦点位于横轴，顶点位于原点双曲线，对应解析式形式为:
#
# ![image.png](attachment:3e7cd372-6c66-4533-aa94-ebf8b951fb8f.png)
#
# 双曲线顶点位于原点，焦点位于 $F_1(-c,0)$ 和 $F_2(c,0)$，$c$ 可以通过下式计算得到：
# $$
# c^2 = a^2 + b^2, c > 0
# $$
#
# ![image.png](attachment:27fb3d52-b45c-4e47-bc5b-26ad693da911.png)

# %% [markdown]
# ### 渐近线、切线斜率

# %% [markdown]
# 双曲线的两条<font color="blue">渐近线</font>(asymptote)表达式如下:
#
# ![image.png](attachment:6c07e1e1-4e4b-443f-b2a1-916be5fc00fc.png)
#
# ![image.png](attachment:227f2d9c-08fb-421a-aff0-7db63808383f.png)
