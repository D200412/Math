# %% [markdown]
# # 5 笛卡尔坐标系(Cartesian Coordinate System)

# %% [markdown]
# ![image.png](attachment:a3979448-128e-464a-8d10-ae8787473827.png)

# %% [markdown]
# ## 5.1 笛卡尔：我思故我在

# %% [markdown]
# <font color="blue">略</font>

# %% [markdown]
# ## 5.2 坐标系：代数可视化，几何参数化

# %% [markdown]
# ### 平面直角坐标系

# %% [markdown]
# 在平面上，<font color="blue">笛卡尔坐标系</font>(Cartesian coordinate system)，也叫平面直角坐标系，是两个相互垂直的实数轴，它们相交于<font color="blue">原点</font>(origin)。数学中，平面直角坐标系常记做 $\mathbb{R}^2$。
#
# <font color="blue">横轴</font>(horizontal number line)常被称作 $x$ 轴(x-axis)，<font color="blue">纵轴</font>(vertical number line)常被称作 $y$ 轴(y-axis)。
#
# ![image.png](attachment:8a14aa1f-8431-46c6-b555-a5d37f2f094d.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [4, 0, -5, -4, -6, 0]
y = [2, -2, 7, -6, -5, 0]

labels = ["A", "B", "C", "D", "E", "O"]

fig, ax = plt.subplots()

plt.plot(x, y, "x")

for label, i, j in zip(labels, x, y):
    plt.text(i, j + 0.5, label + f"({i},{j})")

plt.xlabel("x")
plt.ylabel("y")
plt.axhline(y=0, color="k", linestyle="-")
plt.axvline(x=0, color="k", linestyle="-")
plt.xticks(np.arange(-8, 8+1, step=1))
plt.yticks(np.arange(-8, 8+1, step=1))
plt.axis("scaled")

ax.set_xlim(-8, 8)
ax.set_ylim(-8, 8)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.grid(linestyle="--", linewidth="0.25", color=[0.5, 0.5, 0.5])

# %% [markdown]
# ### 欧几里得的五个公理

# %% [markdown]
# #### 直线

# %% [markdown]
# 平面直角坐标系中，任意两点可以画一条直线，这条直线一般对应代数中的二元一次方程:
#
# ![image.png](attachment:4928ca5c-13b9-4997-ba54-de7c48e2ec51.png)
#
# ![image.png](attachment:14523191-c3af-492d-99c6-81de62c6db33.png)
#
# $-a/b$ 为直线<font color="blue">斜率</font>(slope)，$-c/b$ 为<font color="blue">纵轴截距</font>(y-intercept)。

# %% [markdown]
# #### 两点距离

# %% [markdown]
# $A(x_A,y_A)$ 和 $B(x_B,y_B)$ 两点之间直线的距离可以用勾股定理获得:
#
# ![image.png](attachment:9873cbc6-c60a-4339-9b7e-71d572702247.png)

# %% [markdown]
# #### 正圆

# %% [markdown]
# ![image.png](attachment:047f1845-4075-49e0-92f4-1597fa3fc9d8.png)
#
# ![image.png](attachment:bfedd61c-1999-4336-9c4a-b46be29dfc71.png)

# %% [markdown]
# 圆心为原点 $(0,0)$ ，半径 $r=1$ 时，圆为<font color="blue">单位圆</font>(unit circle)

# %% [markdown]
# #### 垂直

# %% [markdown]
# 如果系数都不为0，两条直线若垂直，则两条直线斜率相乘为-1。

# %% [markdown]
# #### 平行

# %% [markdown]
# 如果系数都不为0，两条直线若平行或重合，则两个斜率相同。

# %%
import numpy as np
import matplotlib.pyplot as plt

def fig_dector(ax):
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.hlines(y=0, xmin=-8, xmax=8, color="k")
    ax.vlines(x=0, ymin=-8, ymax=8, color="k")

    ax.set_xticks(np.arange(-8, 8+1, step=1))
    ax.set_yticks(np.arange(-8, 8+1, step=1))

    ax.axis("scaled")
    ax.grid(linestyle="--", linewidth=0.25, color=[0.5, 0.5, 0.5])

    ax.set_xbound(lower=-8, upper=8)
    ax.set_ybound(lower=-8, upper=8)
    ax.spines["top"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(False)

x_array = np.linspace(-8, 8)
y_array = np.linspace(-8, 8)

# orthogomal
fig, ax = plt.subplots()

y1 = 0.5 *  x_array + 2
y2 = -2 * x_array -1

ax.plot(x_array, y1)
ax.plot(x_array, y2)
fig_dector(ax)

# parallel

y1 = 0.5 * x_array + 2
y2 = 0.5 * x_array - 4

ax.plot(x_array, y1)
ax.plot(x_array, y2)
fig_dector(ax)

# %% [markdown]
# ## 5.3 图解 “鸡兔同笼” 问题

# %% [markdown]
# ### 图解法

# %% [markdown]
# ![image.png](attachment:3cacb2dd-d94b-4ccc-a35d-72638160bc36.png)

# %% [markdown]
# ### 限制条件

# %% [markdown]
# 鸡兔同笼问题还隐含着限制条件—$x_i$ 和 $x_2$均为非负整数；也就是说，鸡、兔的个数必须是0或正整数，不能是小数，更不能是负数。

# %% [markdown]
# ### 二元一次方程组解的个数

# %% [markdown]
# ![image.png](attachment:85cacdba-0717-4085-ba88-7fac068524b9.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 设置全局图形尺寸：宽 7.50 英寸，高 3.50 英寸
plt.rcParams["figure.figsize"] = [7.50, 3.50]

# 启用自动布局，自动调整子图参数，避免标签、标题等重叠
plt.rcParams["figure.autolayout"] = True

x_array = np.arange(0, 30 + 1, step=1)
y_line_1 = 35 - x_array
y_line_2 = (94 - 2 * x_array) / 4

fig, ax = plt.subplots()

plt.plot(x_array, y_line_1, color="#0070C0")
plt.plot(x_array, y_line_2, color="g")

# solution of linear equations
plt.plot(23, 12, marker="x", markersize=12)
plt.axvline(x=23, color="r", linestyle="--")
plt.axhline(y=12, color="r", linestyle="--")

plt.xlabel("$x_1$ (number of chickens)")
plt.ylabel("$x_2$ (number of rabbits)")
plt.axhline(y=0, color="k", linestyle="-")
plt.axvline(x=0, color="k", linestyle="-")
plt.xticks(np.arange(0, 30+1, step=5))
plt.yticks(np.arange(0, 30+1, step=5))
# 设置坐标轴比例相等，即 x 轴和 y 轴的单位长度相同，保证图形不变形
plt.axis("scaled")
# 打开次要刻度线（minor ticks）
plt.minorticks_on()
ax.grid(which="minor", linestyle=":", linewidth="0.5", color=[0.8, 0.8, 0.8])
ax.set_xlim(0,30)
ax.set_ylim(0,30)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.grid(linestyle="--", linewidth=0.25, color=[0.5, 0.5, 0.5])

# %% [markdown]
# ## 5.4 极坐标：距离和夹角

# %% [markdown]
# <font color="blue">极坐标系</font>(polar coordinate system)也是常用坐标系。

# %% [markdown]
# $O$ 是极坐标的<font color="blue">极点</font>(pole)，从 $O$ 向右引一条射线作为<font color="blue">极轴</font>(polaraxis)。
#
# $r$ 称为极径(radial coordinate 或 radial distance), $\theta$ 称为极角(angular coordinate 或 polarangle 或 azimuth)。
#
# ![image.png](attachment:6c4c5119-66cb-4043-8127-7f399eeacabe.png)

# %% [markdown]
# 平面上，极坐标 $(r,θ)$ 可以转化为直角坐标系坐标 $(x_1,x_2)$:
#
# ![image.png](attachment:94223ea4-b8f2-4af3-8831-4fdc282a8b35.png)

# %% [markdown]
# <font color="blue">阿基米德螺旋线</font>(Archimedean spiral)
#
# ![image.png](attachment:388cd3be-6ee1-4f24-9be1-5c3dd4eb933a.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_polar(theta, r):
    # subplot_kw 用字典指定 projection="polar"，表示使用极坐标投影
    fig, ax = plt.subplots(subplot_kw={"projection": "polar"})
    ax.plot(theta, r)
    # set radial axis limit
    ax.set_rmax(20)
    # set radial axis ticks
    ax.set_rticks([5, 10, 15, 20])
    # position radial labels
    # 设置 r 轴刻度标签的显示角度为 -45 度
    ax.set_rlabel_position(-45)
    ax.grid(True)
    plt.show()

# 生成 1000 个角度值，范围从 0 到 6π，约等于转 3 圈
theta = np.linspace(0, 6 * np.pi, 1000)

# %%
# circle
r = 10 + theta * 0
plot_polar(theta, r)

# %%
# Archimedes' spiral
r = 1 * theta
plot_polar(theta, r)

# %%
# Rose
r = 10 * np.cos(6 * theta) + 10
plot_polar(theta, r)

# %% [markdown]
# ## 5.5 参数方程：引入一个参数

# %% [markdown]
# 在平面直角坐标系中，如果曲线上任意一点坐标 $x$、$y$ 都是某个参数，比如 $t$ 的函数:对于 $t$ 的任何取值，方程组确定的点 $(x,y)$ 都在这条曲线上，那么这个方程就叫做曲线的<font color="blue">参数方程</font>(parametric equation)，$t$ 简称为参数
#
# ![image.png](attachment:cbba5f24-e3c9-4177-b873-38662181fcd6.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 2*np.pi, 100)

# parametric equation of unit circle
x1 = np.cos(t)
x2 = np.sin(t)

fig, ax = plt.subplots()

# plot the circle
plt.plot(x1, x2)


ax.set_xlabel("$x_1$")
ax.set_ylabel("$x_2$")
ax.set_xticks(np.arange(-2, 2 + 1, step=1))
ax.set_yticks(np.arange(-2, 2 + 1, step=1))
ax.axis("scaled")
ax.grid(linestyle="--", linewidth=0.25, color=[0.7, 0.7, 0.7])
ax.set_xbound(lower=-2, upper=2)
ax.set_ybound(lower=-2, upper=2)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["left"].set_visible(False)
plt.gca().spines["bottom"].set_visible(False)
plt.axhline(y=0, color="k", linestyle="-")
plt.axvline(x=0, color="k", linestyle="-")
plt.show()

# %%
from sympy import *
from sympy.plotting import plot_parametric
import math

t = symbols("t")

# paramtric equation of unit circle
x1 = cos(t)
x2 = sin(t)

# plot the circle
plot_parametric(x1, x2, (t, 0, 2 * pi), size=(10, 10))

# %% [markdown]
# ## 5.6 坐标系必须是“横平竖直的方格”？

# %% [markdown]
# ![image.png](attachment:51fb1eeb-df07-41b8-a6e3-a378454dd441.png)
